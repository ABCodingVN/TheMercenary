# %%
import pandas as pd

namefile='thoi_trang'
df = pd.read_csv(f'./{namefile}_data.csv')
df
# Out:
#      Unnamed: 0         id                                               name  \
# 0             0   55642260            Đầm Nữ Trễ Vai Tay Phối Lưới Thời Trang
# 1             1  158085449  Đầm Váy Nữ Giá Rẻ Bèo Ngực Đính Nút Thời Trang...
# 2             2  104559668                Đầm Voan Nữ Họa Tiết Hoa Thời Trang
# 3             3  152845926  Đầm cổ vuông tay phồng đính nút ngọc tiểu thư ...
# 4             4   84551579      ĐẦM THỜI TRANG NỮ DỄ THƯƠNG DÁNG XÒE BIG SIZE
# ..          ...        ...                                                ...
# 995         995  112623482      Túi đựng mỹ phẩm cho nam và nữ khi đi du lịch
# 996         996  106551329  Sports Sunglasses Computer Anti Blue-ray Glass...
# 997         997   95663634  5x Mans Stainless Steel Slim Money Clip Wallet...
# 998         998  123719120  2021Men Quần Lót Cotton Nam Nguyên Chất Nam Qu...
# 999         999  119006522                             Ba Lô Urban life style
#
#                                          thumbnail_url  \
# 0    https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1    https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2    https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3    https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4    https://salt.tikicdn.com/cache/280x280/ts/prod...
# ..                                                 ...
# 995  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 996  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 997  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 998  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 999  https://salt.tikicdn.com/cache/280x280/ts/prod...
#
#                                      short_description
# 0    <p>Freesize cho người từ 40kg đến 53kg</p><p>G...
# 1    <html>\n <head></head>\n <body>\n  <ul>\n   <p...
# 2    <h1 style="text-align: center;"><strong><em>Đầ...
# 3    <p>Đầm cổ vuông tay phồng nút ngọc form dài ma...
# 4    <p>- Đầm thiết kế trẻ trung</p>\n<p>- Màu sắc ...
# ..                                                 ...
# 995  This toiletry bag is made with PVC material, w...
# 996  <html>\n <head></head>\n <body>\n  <p>Descript...
# 997  <html>\n <head></head>\n <body>\n  <p><b>Packa...
# 998  <html>\n <head></head>\n <body>\n  <div>\n   <...
# 999  <html>\n <head></head>\n <body>\n  <ul>\n   <p...
#
# [1000 rows x 5 columns]

# %%
# insert into Products values('PD01','SPL01','CT01','RT01', 'Smart Tivi Samsung 4K 50 inch UA50AU7700','https://salt.tikicdn.com/cache/400x400/ts/product/3a/0c/fe/09bbf1fad770994003014fcaa748b37d.jpg.webp', 11737700, 'PurColor Tái Hiện Sắc Màu Cuộc Sống, Rực Rỡ Và Sống Động Hơn Smart Tivi Samsung 4K 50 inch UA50AU7700 Mới 2021 - Choáng ngợp trước dải màu sắc hiển thị rộng lớn và rực rỡ từ công nghệ PurColor. Đắm chìm trong từng khung hình sống động và chân thực như bước ra từ cuộc sống.',20, 'null', 'null','Hàn Quốc', 'Hàn Quốc', 'SamSung', 21/01/2030  )
from numpy import savetxt


sql=""
for index, row in df.iterrows():
   sql=sql+f"insert into Products values('{row['id']}','SPL01','CT16','RT01', '{row['name']}','{row['thumbnail_url']}', 1237700,'{row['short_description']}',20, 'null', 'null','Việt Nam', 'Việt Nam', 'ChinSu', 21/01/2030  )\n"
with open(f'{namefile}.sql', 'w',encoding='UTF8') as file:
  file.write(sql)
file.close()
